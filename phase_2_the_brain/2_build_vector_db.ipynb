# %%
# Install Required Packages
# !pip install google-generativeai chromadb
# Out:
# Requirement already satisfied: google-generativeai in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.8.5)
# Requirement already satisfied: chromadb in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.0.13)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.173.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.40.3)
# Requirement already satisfied: protobuf in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (2.11.7)
# Requirement already satisfied: tqdm in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-generativeai) (4.13.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core->google-generativeai) (2.32.4)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (2.1.3)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: sympy in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic->google-generativeai) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tokenizers>=0.13.2->chromadb) (0.33.0)
# Requirement already satisfied: filelock in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sanket\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
# --- IMPORTS AND CONFIGURATION ---
import json
import os
import sys
import time
import glob
import chromadb
import google.generativeai as genai
from google.api_core.exceptions import GoogleAPICallError

# Directory containing all knowledge base JSON files
KNOWLEDGE_BASE_DIR = '../phase_1_knowledge_base/knowledge_base/'

# The directory where the vector database will be stored.
CHROMA_PATH = 'chroma_db'

# The Gemini model used to create the embeddings.
EMBEDDING_MODEL_NAME = 'models/embedding-001'

# The name of the collection within the ChromaDB database.
COLLECTION_NAME = 'pet_health_kb'

print("Configuration loaded.")
# Out:
# Configuration loaded.

# %%
# --- CONFIGURE GEMINI API ---
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    # A simple way to prompt for the key if it's not set as an environment variable
    # Note: In a shared or production environment, using environment variables is more secure.
    try:
        from google.colab import userdata
        api_key = userdata.get('GOOGLE_API_KEY')
        print("API Key loaded from Colab secrets.")
    except (ImportError, KeyError):
        api_key = input("Please enter your Google API Key: ")
        
genai.configure(api_key=api_key)

print(f"Gemini API configured using model: {EMBEDDING_MODEL_NAME}")
# Out:
# Gemini API configured using model: models/embedding-001

# %%
# --- HELPER FUNCTIONS ---

def load_and_combine_documents(directory):
    """Loads and combines all JSON documents from a directory."""
    all_docs = []
    json_files = glob.glob(os.path.join(directory, '*.json'))
    print(f"Found {len(json_files)} JSON files in {directory}.")
    for file_path in json_files:
        print(f"  Loading: {file_path}")
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                docs = json.load(f)
                if isinstance(docs, list):
                    all_docs.extend(docs)
                elif isinstance(docs, dict):
                    all_docs.append(docs)
        except Exception as e:
            print(f"    Error loading {file_path}: {e}")
    print(f"Total combined documents: {len(all_docs)}")
    return all_docs

def get_embedding(text, model_name):
    """Generates an embedding for a given text using the Gemini API."""
    try:
        return genai.embed_content(model=model_name, content=text)["embedding"]
    except Exception as e:
        print(f"Error embedding text: '{text[:50]}...'. Error: {e}")
        return None

print("Helper functions defined.")
# Out:
# Helper functions defined.

# %%
# --- MAIN SCRIPT LOGIC ---
print("--- Starting Phase 2: Building the Vector Database ---")

# 1. Load and combine all knowledge base documents
all_documents = load_and_combine_documents(KNOWLEDGE_BASE_DIR)
print(f"Loaded {len(all_documents)} document chunks from all JSON files.")

# 2. Initialize ChromaDB client and collection
client = chromadb.PersistentClient(path=CHROMA_PATH)
collection = client.get_or_create_collection(
    name=COLLECTION_NAME,
    metadata={"hnsw:space": "cosine"} # Using cosine distance is good for semantic search
)
print(f"ChromaDB collection '{COLLECTION_NAME}' is ready.")
print(f"Database will be saved in: {os.path.abspath(CHROMA_PATH)}")

# 3. Embed and store each document
print("\nProcessing and embedding documents...")
count = 0
for i, doc in enumerate(all_documents):
    chunk_text = doc.get('chunk')
    source_url = doc.get('source')
    doc_id = str(i)
    # Check if document already exists to avoid re-processing
    if len(collection.get(ids=[doc_id])['ids']) > 0:
        print(f"  Document ID {doc_id} already exists. Skipping.")
        continue
    if not chunk_text:
        print(f"  Skipping document {i} due to missing 'chunk' field.")
        continue
    embedding = get_embedding(chunk_text, EMBEDDING_MODEL_NAME)
    if embedding:
        collection.add(
            embeddings=[embedding],
            documents=[chunk_text],
            metadatas=[{"source": source_url}],
            ids=[doc_id]
        )
        count += 1
        print(f"  -> Added document {i+1}/{len(all_documents)} (ID: {doc_id})")
        time.sleep(0.1) # Small delay to be kind to the API
    else:
        print(f"  -> FAILED to process document {i+1}. Skipping.")

print("\n--- Phase 2 Complete ---")
print(f"Successfully added {count} new documents to the '{COLLECTION_NAME}' collection.")
print(f"Total documents in collection: {collection.count()}")
# Out:
# --- Starting Phase 2: Building the Vector Database ---
# Found 3 JSON files in ../phase_1_knowledge_base/knowledge_base/.
#   Loading: ../phase_1_knowledge_base/knowledge_base\final_pet_health_kb.json
#   Loading: ../phase_1_knowledge_base/knowledge_base\pet_health_data.json
#   Loading: ../phase_1_knowledge_base/knowledge_base\universal_pet_health_data.json
# Total combined documents: 252
# Loaded 252 document chunks from all JSON files.
# ChromaDB collection 'pet_health_kb' is ready.
# Database will be saved in: d:\mini project\pet_care_chatbot\phase_2_the_brain\chroma_db
#
# Processing and embedding documents...
#   Document ID 0 already exists. Skipping.
#   Document ID 1 already exists. Skipping.
#   Document ID 2 already exists. Skipping.
#   Document ID 3 already exists. Skipping.
#   Document ID 4 already exists. Skipping.
#   Document ID 5 already exists. Skipping.
#   Document ID 6 already exists. Skipping.
#   Document ID 7 already exists. Skipping.
#   Document ID 8 already exists. Skipping.
#   Document ID 9 already exists. Skipping.
#   Document ID 10 already exists. Skipping.
#   Document ID 11 already exists. Skipping.
#   Document ID 12 already exists. Skipping.
#   Document ID 13 already exists. Skipping.
#   Document ID 14 already exists. Skipping.
#   Document ID 15 already exists. Skipping.
#   Document ID 16 already exists. Skipping.
#   Document ID 17 already exists. Skipping.
#   Document ID 18 already exists. Skipping.
#   Document ID 19 already exists. Skipping.
#   Document ID 20 already exists. Skipping.
#   Document ID 21 already exists. Skipping.
#   Document ID 22 already exists. Skipping.
#   Document ID 23 already exists. Skipping.
#   Document ID 24 already exists. Skipping.
#   Document ID 25 already exists. Skipping.
#   Document ID 26 already exists. Skipping.
#   Document ID 27 already exists. Skipping.
#   Document ID 28 already exists. Skipping.
#   Document ID 29 already exists. Skipping.
#   Document ID 30 already exists. Skipping.
#   Document ID 31 already exists. Skipping.
#   Document ID 32 already exists. Skipping.
#   Document ID 33 already exists. Skipping.
#   Document ID 34 already exists. Skipping.
#   Document ID 35 already exists. Skipping.
#   Document ID 36 already exists. Skipping.
#   Document ID 37 already exists. Skipping.
#   Document ID 38 already exists. Skipping.
#   Document ID 39 already exists. Skipping.
#   Document ID 40 already exists. Skipping.
#   Document ID 41 already exists. Skipping.
#   Document ID 42 already exists. Skipping.
#   Document ID 43 already exists. Skipping.
#   Document ID 44 already exists. Skipping.
#   Document ID 45 already exists. Skipping.
#   Document ID 46 already exists. Skipping.
#   Document ID 47 already exists. Skipping.
#   Document ID 48 already exists. Skipping.
#   Document ID 49 already exists. Skipping.
#   Document ID 50 already exists. Skipping.
#   Document ID 51 already exists. Skipping.
#   Document ID 52 already exists. Skipping.
#   Document ID 53 already exists. Skipping.
#   Document ID 54 already exists. Skipping.
#   Document ID 55 already exists. Skipping.
#   Document ID 56 already exists. Skipping.
#   Document ID 57 already exists. Skipping.
#   Document ID 58 already exists. Skipping.
#   Document ID 59 already exists. Skipping.
#   Document ID 60 already exists. Skipping.
#   Document ID 61 already exists. Skipping.
#   Document ID 62 already exists. Skipping.
#   Document ID 63 already exists. Skipping.
#   Document ID 64 already exists. Skipping.
#   Document ID 65 already exists. Skipping.
#   Document ID 66 already exists. Skipping.
#   Document ID 67 already exists. Skipping.
#   Document ID 68 already exists. Skipping.
#   Document ID 69 already exists. Skipping.
#   Document ID 70 already exists. Skipping.
#   Document ID 71 already exists. Skipping.
#   Document ID 72 already exists. Skipping.
#   Document ID 73 already exists. Skipping.
#   Document ID 74 already exists. Skipping.
#   Document ID 75 already exists. Skipping.
#   Document ID 76 already exists. Skipping.
#   Document ID 77 already exists. Skipping.
#   Document ID 78 already exists. Skipping.
#   Document ID 79 already exists. Skipping.
#   Document ID 80 already exists. Skipping.
#   Document ID 81 already exists. Skipping.
#   Document ID 82 already exists. Skipping.
#   Document ID 83 already exists. Skipping.
#   -> Added document 85/252 (ID: 84)
#   -> Added document 85/252 (ID: 84)
#   -> Added document 86/252 (ID: 85)
#   -> Added document 86/252 (ID: 85)
#   -> Added document 87/252 (ID: 86)
#   -> Added document 87/252 (ID: 86)
#   -> Added document 88/252 (ID: 87)
#   -> Added document 88/252 (ID: 87)
#   -> Added document 89/252 (ID: 88)
#   -> Added document 89/252 (ID: 88)
#   -> Added document 90/252 (ID: 89)
#   -> Added document 90/252 (ID: 89)
#   -> Added document 91/252 (ID: 90)
#   -> Added document 91/252 (ID: 90)
#   -> Added document 92/252 (ID: 91)
#   -> Added document 92/252 (ID: 91)
#   -> Added document 93/252 (ID: 92)
#   -> Added document 93/252 (ID: 92)
#   -> Added document 94/252 (ID: 93)
#   -> Added document 94/252 (ID: 93)
#   -> Added document 95/252 (ID: 94)
#   -> Added document 95/252 (ID: 94)
#   -> Added document 96/252 (ID: 95)
#   -> Added document 96/252 (ID: 95)
#   -> Added document 97/252 (ID: 96)
#   -> Added document 97/252 (ID: 96)
#   -> Added document 98/252 (ID: 97)
#   -> Added document 98/252 (ID: 97)
#   -> Added document 99/252 (ID: 98)
#   -> Added document 99/252 (ID: 98)
#   -> Added document 100/252 (ID: 99)
#   -> Added document 100/252 (ID: 99)
#   -> Added document 101/252 (ID: 100)
#   -> Added document 101/252 (ID: 100)
#   -> Added document 102/252 (ID: 101)
#   -> Added document 102/252 (ID: 101)
#   -> Added document 103/252 (ID: 102)
#   -> Added document 103/252 (ID: 102)
#   -> Added document 104/252 (ID: 103)
#   -> Added document 104/252 (ID: 103)
#   -> Added document 105/252 (ID: 104)
#   -> Added document 105/252 (ID: 104)
#   -> Added document 106/252 (ID: 105)
#   -> Added document 222/252 (ID: 221)
#   -> Added document 223/252 (ID: 222)
#   -> Added document 223/252 (ID: 222)
#   -> Added document 224/252 (ID: 223)
#   -> Added document 224/252 (ID: 223)
#   -> Added document 225/252 (ID: 224)
#   -> Added document 225/252 (ID: 224)
#   -> Added document 226/252 (ID: 225)
#   -> Added document 226/252 (ID: 225)
#   -> Added document 227/252 (ID: 226)
#   -> Added document 227/252 (ID: 226)
#   -> Added document 228/252 (ID: 227)
#   -> Added document 228/252 (ID: 227)
#   -> Added document 229/252 (ID: 228)
#   -> Added document 229/252 (ID: 228)
#   -> Added document 230/252 (ID: 229)
#   -> Added document 230/252 (ID: 229)
#   -> Added document 231/252 (ID: 230)
#   -> Added document 231/252 (ID: 230)
#   -> Added document 232/252 (ID: 231)
#   -> Added document 232/252 (ID: 231)
#   -> Added document 233/252 (ID: 232)
#   -> Added document 233/252 (ID: 232)
#   -> Added document 234/252 (ID: 233)
#   -> Added document 234/252 (ID: 233)
#   -> Added document 235/252 (ID: 234)
#   -> Added document 235/252 (ID: 234)
#   -> Added document 236/252 (ID: 235)
#   -> Added document 236/252 (ID: 235)
#   -> Added document 237/252 (ID: 236)
#   -> Added document 237/252 (ID: 236)
#   -> Added document 238/252 (ID: 237)
#   -> Added document 238/252 (ID: 237)
#   -> Added document 239/252 (ID: 238)
#   -> Added document 239/252 (ID: 238)
#   -> Added document 240/252 (ID: 239)
#   -> Added document 240/252 (ID: 239)
#   -> Added document 241/252 (ID: 240)
#   -> Added document 241/252 (ID: 240)
#   -> Added document 242/252 (ID: 241)
#   -> Added document 242/252 (ID: 241)
#   -> Added document 243/252 (ID: 242)
#   -> Added document 243/252 (ID: 242)
#   -> Added document 244/252 (ID: 243)
#   -> Added document 244/252 (ID: 243)
#   -> Added document 245/252 (ID: 244)
#   -> Added document 245/252 (ID: 244)
#   -> Added document 246/252 (ID: 245)
#   -> Added document 246/252 (ID: 245)
#   -> Added document 247/252 (ID: 246)
#   -> Added document 247/252 (ID: 246)
#   -> Added document 248/252 (ID: 247)
#   -> Added document 248/252 (ID: 247)
#   -> Added document 249/252 (ID: 248)
#   -> Added document 249/252 (ID: 248)
#   -> Added document 250/252 (ID: 249)
#   -> Added document 250/252 (ID: 249)
#   -> Added document 251/252 (ID: 250)
#   -> Added document 251/252 (ID: 250)
#   -> Added document 252/252 (ID: 251)
#
# --- Phase 2 Complete ---
# Successfully added 168 new documents to the 'pet_health_kb' collection.
# Total documents in collection: 252
#   -> Added document 252/252 (ID: 251)
#
# --- Phase 2 Complete ---
# Successfully added 168 new documents to the 'pet_health_kb' collection.
# Total documents in collection: 252

# %%
# Vector Database Build Complete

'''All knowledge base JSON files have been combined and embedded into the ChromaDB vector database.

**Next steps:**
- You can now use this vector database for semantic search or chatbot applications.
- Proceed to the next phase for retrieval or inference tasks.'''
# Out:
# 'All knowledge base JSON files have been combined and embedded into the ChromaDB vector database.\n\n**Next steps:**\n- You can now use this vector database for semantic search or chatbot applications.\n- Proceed to the next phase for retrieval or inference tasks.'
